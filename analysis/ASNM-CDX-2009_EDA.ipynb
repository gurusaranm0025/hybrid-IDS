# %%
import pandas as pd
import numpy as np

from analysis_src.basic_data_inspection import DataInspector, DataTypeInspectionStrategy, SummaryStatisticsInspectionStrategy
from analysis_src.missing_value_analysis import SimpleMissingValueAnalysis

# %%
dataset_path = "../extracted_data/ASNM-CDX-2009.csv"
df = pd.read_csv(dataset_path, sep=";")
df.head()
# Out:
#    id  label_2 label_poly        SrcIP        DstIP  SrcPort  DstPort  \
# 0   1    False    0_other  10.1.60.203   10.1.60.73    63637     5222
# 1   2    False   0_apache   10.1.10.69  10.1.60.187     2201       80
# 2   3    False   0_apache   10.1.10.69  10.1.60.187     2201       80
# 3   4    False    0_other   10.1.10.69  10.1.60.187     2202      443
# 4   5    False   0_apache   10.1.10.69  10.1.60.187     2203       80
#
#               SrcMAC             DstMAC  SrcIPInVlan  ...  GaussProds4All[2]  \
# 0  00:0C:29:D7:B7:89  00:1A:6C:FB:3D:F0         True  ...          39.854715
# 1  00:1E:7A:21:B4:00  00:1A:6C:FB:3D:F0        False  ...          42.446332
# 2  00:1E:7A:21:B4:00  00:1A:6C:FB:3D:F0        False  ...          62.828639
# 3  00:1E:7A:21:B4:00  00:1A:6C:FB:3D:F0        False  ...          42.162261
# 4  00:1E:7A:21:B4:00  00:1A:6C:FB:3D:F0        False  ...          62.828639
#
#    GaussProds4All[3]  GaussProds8All[0]  GaussProds8All[1]  GaussProds8All[2]  \
# 0          13.226058          30.142188          27.376107          65.213653
# 1          10.750317          25.283971          25.283971          15.870392
# 2          12.236273          25.275107          26.156893         175.667483
# 3          11.164318          25.275107          24.760861          25.046723
# 4          12.236273          25.275107          26.156893         175.667483
#
#    GaussProds8All[3]  GaussProds8All[4]  GaussProds8All[5]  GaussProds8All[6]  \
# 0          28.129521          98.002262          34.486082          26.990536
# 1         175.667483          27.907473          62.828639          26.862012
# 2          27.907473         182.848444          26.254394          26.862012
# 3         478.845737          99.885190          19.688286          31.250377
# 4          27.907473         182.848444          26.254394          26.862012
#
#    GaussProds8All[7]
# 0          16.262570
# 1          14.797450
# 2          14.797450
# 3          14.821825
# 4          14.797450
#
# [5 rows x 877 columns]

# %%
# Basic Data Inspection : Data Type Inspection
data_inspector = DataInspector(DataTypeInspectionStrategy())
data_inspector.execute_inspection(df)
# Out:
# Data Types and Non-Null counts:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5771 entries, 0 to 5770
# Columns: 877 entries, id to GaussProds8All[7]
# dtypes: bool(5), float64(331), int64(536), object(5)
# memory usage: 38.4+ MB
# None
#
# Printing all the columns and their data type:
# Column: id, Data type: int64
# Column: label_2, Data type: bool
# Column: label_poly, Data type: object
# Column: SrcIP, Data type: object
# Column: DstIP, Data type: object
# Column: SrcPort, Data type: int64
# Column: DstPort, Data type: int64
# Column: SrcMAC, Data type: object
# Column: DstMAC, Data type: object
# Column: SrcIPInVlan, Data type: bool
# Column: DstIPInVlan, Data type: bool
# Column: InPkt1s10i[0], Data type: int64
# Column: InPkt1s10i[1], Data type: int64
# Column: InPkt1s10i[2], Data type: int64
# Column: InPkt1s10i[3], Data type: int64
# Column: InPkt1s10i[4], Data type: int64
# Column: InPkt1s10i[5], Data type: int64
# Column: InPkt1s10i[6], Data type: int64
# Column: InPkt1s10i[7], Data type: int64
# Column: InPkt1s10i[8], Data type: int64
# Column: InPkt1s10i[9], Data type: int64
# Column: InPkt4s10i[0], Data type: int64
# Column: InPkt4s10i[1], Data type: int64
# Column: InPkt4s10i[2], Data type: int64
# Column: InPkt4s10i[3], Data type: int64
# Column: InPkt4s10i[4], Data type: int64
# Column: InPkt4s10i[5], Data type: int64
# Column: InPkt4s10i[6], Data type: int64
# Column: InPkt4s10i[7], Data type: int64
# Column: InPkt4s10i[8], Data type: int64
# Column: InPkt4s10i[9], Data type: int64
# Column: InPkt8s10i[0], Data type: int64
# Column: InPkt8s10i[1], Data type: int64
# Column: InPkt8s10i[2], Data type: int64
# Column: InPkt8s10i[3], Data type: int64
# Column: InPkt8s10i[4], Data type: int64
# Column: InPkt8s10i[5], Data type: int64
# Column: InPkt8s10i[6], Data type: int64
# Column: InPkt8s10i[7], Data type: int64
# Column: InPkt8s10i[8], Data type: int64
# Column: InPkt8s10i[9], Data type: int64
# Column: InPkt32s10i[0], Data type: int64
# Column: InPkt32s10i[1], Data type: int64
# Column: InPkt32s10i[2], Data type: int64
# Column: InPkt32s10i[3], Data type: int64
# Column: InPkt32s10i[4], Data type: int64
# Column: InPkt32s10i[5], Data type: int64
# Column: InPkt32s10i[6], Data type: int64
# Column: InPkt32s10i[7], Data type: int64
# Column: InPkt32s10i[8], Data type: int64
# Column: InPkt32s10i[9], Data type: int64
# Column: InPkt64s10i[0], Data type: int64
# Column: InPkt64s10i[1], Data type: int64
# Column: InPkt64s10i[2], Data type: int64
# Column: InPkt64s10i[3], Data type: int64
# Column: InPkt64s10i[4], Data type: int64
# Column: InPkt64s10i[5], Data type: int64
# Column: InPkt64s10i[6], Data type: int64
# Column: InPkt64s10i[7], Data type: int64
# Column: InPkt64s10i[8], Data type: int64
# Column: InPkt64s10i[9], Data type: int64
# Column: OutPkt1s10i[0], Data type: int64
# Column: OutPkt1s10i[1], Data type: int64
# Column: OutPkt1s10i[2], Data type: int64
# Column: OutPkt1s10i[3], Data type: int64
# Column: OutPkt1s10i[4], Data type: int64
# Column: OutPkt1s10i[5], Data type: int64
# Column: OutPkt1s10i[6], Data type: int64
# Column: OutPkt1s10i[7], Data type: int64
# Column: OutPkt1s10i[8], Data type: int64
# Column: OutPkt1s10i[9], Data type: int64
# Column: OutPkt4s10i[0], Data type: int64
# Column: OutPkt4s10i[1], Data type: int64
# Column: OutPkt4s10i[2], Data type: int64
# Column: OutPkt4s10i[3], Data type: int64
# Column: OutPkt4s10i[4], Data type: int64
# Column: OutPkt4s10i[5], Data type: int64
# Column: OutPkt4s10i[6], Data type: int64
# Column: OutPkt4s10i[7], Data type: int64
# Column: OutPkt4s10i[8], Data type: int64
# Column: OutPkt4s10i[9], Data type: int64
# Column: OutPkt8s10i[0], Data type: int64
# Column: OutPkt8s10i[1], Data type: int64
# Column: OutPkt8s10i[2], Data type: int64
# Column: OutPkt8s10i[3], Data type: int64
# Column: OutPkt8s10i[4], Data type: int64
# Column: OutPkt8s10i[5], Data type: int64
# Column: OutPkt8s10i[6], Data type: int64
# Column: OutPkt8s10i[7], Data type: int64
# Column: OutPkt8s10i[8], Data type: int64
# Column: OutPkt8s10i[9], Data type: int64
# Column: OutPkt32s10i[0], Data type: int64
# Column: OutPkt32s10i[1], Data type: int64
# Column: OutPkt32s10i[2], Data type: int64
# Column: OutPkt32s10i[3], Data type: int64
# Column: OutPkt32s10i[4], Data type: int64
# Column: OutPkt32s10i[5], Data type: int64
# Column: OutPkt32s10i[6], Data type: int64
# Column: OutPkt32s10i[7], Data type: int64
# Column: OutPkt32s10i[8], Data type: int64
# Column: OutPkt32s10i[9], Data type: int64
# Column: OutPkt64s10i[0], Data type: int64
# Column: OutPkt64s10i[1], Data type: int64
# Column: OutPkt64s10i[2], Data type: int64
# Column: OutPkt64s10i[3], Data type: int64
# Column: OutPkt64s10i[4], Data type: int64
# Column: OutPkt64s10i[5], Data type: int64
# Column: OutPkt64s10i[6], Data type: int64
# Column: OutPkt64s10i[7], Data type: int64
# Column: OutPkt64s10i[8], Data type: int64
# Column: OutPkt64s10i[9], Data type: int64
# Column: InPktLen1s10i[0], Data type: int64
# Column: InPktLen1s10i[1], Data type: int64
# Column: InPktLen1s10i[2], Data type: int64
# Column: InPktLen1s10i[3], Data type: int64
# Column: InPktLen1s10i[4], Data type: int64
# Column: InPktLen1s10i[5], Data type: int64
# Column: InPktLen1s10i[6], Data type: int64
# Column: InPktLen1s10i[7], Data type: int64
# Column: InPktLen1s10i[8], Data type: int64
# Column: InPktLen1s10i[9], Data type: int64
# Column: InPktLen4s10i[0], Data type: int64
# Column: InPktLen4s10i[1], Data type: int64
# Column: InPktLen4s10i[2], Data type: int64
# Column: InPktLen4s10i[3], Data type: int64
# Column: InPktLen4s10i[4], Data type: int64
# Column: InPktLen4s10i[5], Data type: int64
# Column: InPktLen4s10i[6], Data type: int64
# Column: InPktLen4s10i[7], Data type: int64
# Column: InPktLen4s10i[8], Data type: int64
# Column: InPktLen4s10i[9], Data type: int64
# Column: InPktLen8s10i[0], Data type: int64
# Column: InPktLen8s10i[1], Data type: int64
# Column: InPktLen8s10i[2], Data type: int64
# Column: InPktLen8s10i[3], Data type: int64
# Column: InPktLen8s10i[4], Data type: int64
# Column: InPktLen8s10i[5], Data type: int64
# Column: InPktLen8s10i[6], Data type: int64
# Column: InPktLen8s10i[7], Data type: int64
# Column: InPktLen8s10i[8], Data type: int64
# Column: InPktLen8s10i[9], Data type: int64
# Column: InPktLen32s10i[0], Data type: int64
# Column: InPktLen32s10i[1], Data type: int64
# Column: InPktLen32s10i[2], Data type: int64
# Column: InPktLen32s10i[3], Data type: int64
# Column: InPktLen32s10i[4], Data type: int64
# Column: InPktLen32s10i[5], Data type: int64
# Column: InPktLen32s10i[6], Data type: int64
# Column: InPktLen32s10i[7], Data type: int64
# Column: InPktLen32s10i[8], Data type: int64
# Column: InPktLen32s10i[9], Data type: int64
# Column: InPktLen64s10i[0], Data type: int64
# Column: InPktLen64s10i[1], Data type: int64
# Column: InPktLen64s10i[2], Data type: int64
# Column: InPktLen64s10i[3], Data type: int64
# Column: InPktLen64s10i[4], Data type: int64
# Column: InPktLen64s10i[5], Data type: int64
# Column: InPktLen64s10i[6], Data type: int64
# Column: InPktLen64s10i[7], Data type: int64
# Column: InPktLen64s10i[8], Data type: int64
# Column: InPktLen64s10i[9], Data type: int64
# Column: OutPktLen1s10i[0], Data type: int64
# Column: OutPktLen1s10i[1], Data type: int64
# Column: OutPktLen1s10i[2], Data type: int64
# Column: OutPktLen1s10i[3], Data type: int64
# Column: OutPktLen1s10i[4], Data type: int64
# Column: OutPktLen1s10i[5], Data type: int64
# Column: OutPktLen1s10i[6], Data type: int64
# Column: OutPktLen1s10i[7], Data type: int64
# Column: OutPktLen1s10i[8], Data type: int64
# Column: OutPktLen1s10i[9], Data type: int64
# Column: OutPktLen4s10i[0], Data type: int64
# Column: OutPktLen4s10i[1], Data type: int64
# Column: OutPktLen4s10i[2], Data type: int64
# Column: OutPktLen4s10i[3], Data type: int64
# Column: OutPktLen4s10i[4], Data type: int64
# Column: OutPktLen4s10i[5], Data type: int64
# Column: OutPktLen4s10i[6], Data type: int64
# Column: OutPktLen4s10i[7], Data type: int64
# Column: OutPktLen4s10i[8], Data type: int64
# Column: OutPktLen4s10i[9], Data type: int64
# Column: OutPktLen8s10i[0], Data type: int64
# Column: OutPktLen8s10i[1], Data type: int64
# Column: OutPktLen8s10i[2], Data type: int64
# Column: OutPktLen8s10i[3], Data type: int64
# Column: OutPktLen8s10i[4], Data type: int64
# Column: OutPktLen8s10i[5], Data type: int64
# Column: OutPktLen8s10i[6], Data type: int64
# Column: OutPktLen8s10i[7], Data type: int64
# Column: OutPktLen8s10i[8], Data type: int64
# Column: OutPktLen8s10i[9], Data type: int64
# Column: OutPktLen32s10i[0], Data type: int64
# Column: OutPktLen32s10i[1], Data type: int64
# Column: OutPktLen32s10i[2], Data type: int64
# Column: OutPktLen32s10i[3], Data type: int64
# Column: OutPktLen32s10i[4], Data type: int64
# Column: OutPktLen32s10i[5], Data type: int64
# Column: OutPktLen32s10i[6], Data type: int64
# Column: OutPktLen32s10i[7], Data type: int64
# Column: OutPktLen32s10i[8], Data type: int64
# Column: OutPktLen32s10i[9], Data type: int64
# Column: OutPktLen64s10i[0], Data type: int64
# Column: OutPktLen64s10i[1], Data type: int64
# Column: OutPktLen64s10i[2], Data type: int64
# Column: OutPktLen64s10i[3], Data type: int64
# Column: OutPktLen64s10i[4], Data type: int64
# Column: OutPktLen64s10i[5], Data type: int64
# Column: OutPktLen64s10i[6], Data type: int64
# Column: OutPktLen64s10i[7], Data type: int64
# Column: OutPktLen64s10i[8], Data type: int64
# Column: OutPktLen64s10i[9], Data type: int64
# Column: InPkt1s20iTr4KB[0], Data type: int64
# Column: InPkt1s20iTr4KB[1], Data type: int64
# Column: InPkt1s20iTr4KB[2], Data type: int64
# Column: InPkt1s20iTr4KB[3], Data type: int64
# Column: InPkt1s20iTr4KB[4], Data type: int64
# Column: InPkt1s20iTr4KB[5], Data type: int64
# Column: InPkt1s20iTr4KB[6], Data type: int64
# Column: InPkt1s20iTr4KB[7], Data type: int64
# Column: InPkt1s20iTr4KB[8], Data type: int64
# Column: InPkt1s20iTr4KB[9], Data type: int64
# Column: InPkt1s20iTr4KB[10], Data type: int64
# Column: InPkt1s20iTr4KB[11], Data type: int64
# Column: InPkt1s20iTr4KB[12], Data type: int64
# Column: InPkt1s20iTr4KB[13], Data type: int64
# Column: InPkt1s20iTr4KB[14], Data type: int64
# Column: InPkt1s20iTr4KB[15], Data type: int64
# Column: InPkt1s20iTr4KB[16], Data type: int64
# Column: InPkt1s20iTr4KB[17], Data type: int64
# Column: InPkt1s20iTr4KB[18], Data type: int64
# Column: InPkt1s20iTr4KB[19], Data type: int64
# Column: InPkt4s20iTr4KB[0], Data type: int64
# Column: InPkt4s20iTr4KB[1], Data type: int64
# Column: InPkt4s20iTr4KB[2], Data type: int64
# Column: InPkt4s20iTr4KB[3], Data type: int64
# Column: InPkt4s20iTr4KB[4], Data type: int64
# Column: InPkt4s20iTr4KB[5], Data type: int64
# Column: InPkt4s20iTr4KB[6], Data type: int64
# Column: InPkt4s20iTr4KB[7], Data type: int64
# Column: InPkt4s20iTr4KB[8], Data type: int64
# Column: InPkt4s20iTr4KB[9], Data type: int64
# Column: InPkt4s20iTr4KB[10], Data type: int64
# Column: InPkt4s20iTr4KB[11], Data type: int64
# Column: InPkt4s20iTr4KB[12], Data type: int64
# Column: InPkt4s20iTr4KB[13], Data type: int64
# Column: InPkt4s20iTr4KB[14], Data type: int64
# Column: InPkt4s20iTr4KB[15], Data type: int64
# Column: InPkt4s20iTr4KB[16], Data type: int64
# Column: InPkt4s20iTr4KB[17], Data type: int64
# Column: InPkt4s20iTr4KB[18], Data type: int64
# Column: InPkt4s20iTr4KB[19], Data type: int64
# Column: InPkt8s20iTr4KB[0], Data type: int64
# Column: InPkt8s20iTr4KB[1], Data type: int64
# Column: InPkt8s20iTr4KB[2], Data type: int64
# Column: InPkt8s20iTr4KB[3], Data type: int64
# Column: InPkt8s20iTr4KB[4], Data type: int64
# Column: InPkt8s20iTr4KB[5], Data type: int64
# Column: InPkt8s20iTr4KB[6], Data type: int64
# Column: InPkt8s20iTr4KB[7], Data type: int64
# Column: InPkt8s20iTr4KB[8], Data type: int64
# Column: InPkt8s20iTr4KB[9], Data type: int64
# Column: InPkt8s20iTr4KB[10], Data type: int64
# Column: InPkt8s20iTr4KB[11], Data type: int64
# Column: InPkt8s20iTr4KB[12], Data type: int64
# Column: InPkt8s20iTr4KB[13], Data type: int64
# Column: InPkt8s20iTr4KB[14], Data type: int64
# Column: InPkt8s20iTr4KB[15], Data type: int64
# Column: InPkt8s20iTr4KB[16], Data type: int64
# Column: InPkt8s20iTr4KB[17], Data type: int64
# Column: InPkt8s20iTr4KB[18], Data type: int64
# Column: InPkt8s20iTr4KB[19], Data type: int64
# Column: InPkt32s20iTr4KB[0], Data type: int64
# Column: InPkt32s20iTr4KB[1], Data type: int64
# Column: InPkt32s20iTr4KB[2], Data type: int64
# Column: InPkt32s20iTr4KB[3], Data type: int64
# Column: InPkt32s20iTr4KB[4], Data type: int64
# Column: InPkt32s20iTr4KB[5], Data type: int64
# Column: InPkt32s20iTr4KB[6], Data type: int64
# Column: InPkt32s20iTr4KB[7], Data type: int64
# Column: InPkt32s20iTr4KB[8], Data type: int64
# Column: InPkt32s20iTr4KB[9], Data type: int64
# Column: InPkt32s20iTr4KB[10], Data type: int64
# Column: InPkt32s20iTr4KB[11], Data type: int64
# Column: InPkt32s20iTr4KB[12], Data type: int64
# Column: InPkt32s20iTr4KB[13], Data type: int64
# Column: InPkt32s20iTr4KB[14], Data type: int64
# Column: InPkt32s20iTr4KB[15], Data type: int64
# Column: InPkt32s20iTr4KB[16], Data type: int64
# Column: InPkt32s20iTr4KB[17], Data type: int64
# Column: InPkt32s20iTr4KB[18], Data type: int64
# Column: InPkt32s20iTr4KB[19], Data type: int64
# Column: InPkt64s20iTr4KB[0], Data type: int64
# Column: InPkt64s20iTr4KB[1], Data type: int64
# Column: InPkt64s20iTr4KB[2], Data type: int64
# Column: InPkt64s20iTr4KB[3], Data type: int64
# Column: InPkt64s20iTr4KB[4], Data type: int64
# Column: InPkt64s20iTr4KB[5], Data type: int64
# Column: InPkt64s20iTr4KB[6], Data type: int64
# Column: InPkt64s20iTr4KB[7], Data type: int64
# Column: InPkt64s20iTr4KB[8], Data type: int64
# Column: InPkt64s20iTr4KB[9], Data type: int64
# Column: InPkt64s20iTr4KB[10], Data type: int64
# Column: InPkt64s20iTr4KB[11], Data type: int64
# Column: InPkt64s20iTr4KB[12], Data type: int64
# Column: InPkt64s20iTr4KB[13], Data type: int64
# Column: InPkt64s20iTr4KB[14], Data type: int64
# Column: InPkt64s20iTr4KB[15], Data type: int64
# Column: InPkt64s20iTr4KB[16], Data type: int64
# Column: InPkt64s20iTr4KB[17], Data type: int64
# Column: InPkt64s20iTr4KB[18], Data type: int64
# Column: InPkt64s20iTr4KB[19], Data type: int64
# Column: OutPkt1s20iTr4KB[0], Data type: int64
# Column: OutPkt1s20iTr4KB[1], Data type: int64
# Column: OutPkt1s20iTr4KB[2], Data type: int64
# Column: OutPkt1s20iTr4KB[3], Data type: int64
# Column: OutPkt1s20iTr4KB[4], Data type: int64
# Column: OutPkt1s20iTr4KB[5], Data type: int64
# Column: OutPkt1s20iTr4KB[6], Data type: int64
# Column: OutPkt1s20iTr4KB[7], Data type: int64
# Column: OutPkt1s20iTr4KB[8], Data type: int64
# Column: OutPkt1s20iTr4KB[9], Data type: int64
# Column: OutPkt1s20iTr4KB[10], Data type: int64
# Column: OutPkt1s20iTr4KB[11], Data type: int64
# Column: OutPkt1s20iTr4KB[12], Data type: int64
# Column: OutPkt1s20iTr4KB[13], Data type: int64
# Column: OutPkt1s20iTr4KB[14], Data type: int64
# Column: OutPkt1s20iTr4KB[15], Data type: int64
# Column: OutPkt1s20iTr4KB[16], Data type: int64
# Column: OutPkt1s20iTr4KB[17], Data type: int64
# Column: OutPkt1s20iTr4KB[18], Data type: int64
# Column: OutPkt1s20iTr4KB[19], Data type: int64
# Column: OutPkt4s20iTr4KB[0], Data type: int64
# Column: OutPkt4s20iTr4KB[1], Data type: int64
# Column: OutPkt4s20iTr4KB[2], Data type: int64
# Column: OutPkt4s20iTr4KB[3], Data type: int64
# Column: OutPkt4s20iTr4KB[4], Data type: int64
# Column: OutPkt4s20iTr4KB[5], Data type: int64
# Column: OutPkt4s20iTr4KB[6], Data type: int64
# Column: OutPkt4s20iTr4KB[7], Data type: int64
# Column: OutPkt4s20iTr4KB[8], Data type: int64
# Column: OutPkt4s20iTr4KB[9], Data type: int64
# Column: OutPkt4s20iTr4KB[10], Data type: int64
# Column: OutPkt4s20iTr4KB[11], Data type: int64
# Column: OutPkt4s20iTr4KB[12], Data type: int64
# Column: OutPkt4s20iTr4KB[13], Data type: int64
# Column: OutPkt4s20iTr4KB[14], Data type: int64
# Column: OutPkt4s20iTr4KB[15], Data type: int64
# Column: OutPkt4s20iTr4KB[16], Data type: int64
# Column: OutPkt4s20iTr4KB[17], Data type: int64
# Column: OutPkt4s20iTr4KB[18], Data type: int64
# Column: OutPkt4s20iTr4KB[19], Data type: int64
# Column: OutPkt8s20iTr4KB[0], Data type: int64
# Column: OutPkt8s20iTr4KB[1], Data type: int64
# Column: OutPkt8s20iTr4KB[2], Data type: int64
# Column: OutPkt8s20iTr4KB[3], Data type: int64
# Column: OutPkt8s20iTr4KB[4], Data type: int64
# Column: OutPkt8s20iTr4KB[5], Data type: int64
# Column: OutPkt8s20iTr4KB[6], Data type: int64
# Column: OutPkt8s20iTr4KB[7], Data type: int64
# Column: OutPkt8s20iTr4KB[8], Data type: int64
# Column: OutPkt8s20iTr4KB[9], Data type: int64
# Column: OutPkt8s20iTr4KB[10], Data type: int64
# Column: OutPkt8s20iTr4KB[11], Data type: int64
# Column: OutPkt8s20iTr4KB[12], Data type: int64
# Column: OutPkt8s20iTr4KB[13], Data type: int64
# Column: OutPkt8s20iTr4KB[14], Data type: int64
# Column: OutPkt8s20iTr4KB[15], Data type: int64
# Column: OutPkt8s20iTr4KB[16], Data type: int64
# Column: OutPkt8s20iTr4KB[17], Data type: int64
# Column: OutPkt8s20iTr4KB[18], Data type: int64
# Column: OutPkt8s20iTr4KB[19], Data type: int64
# Column: OutPkt32s20iTr4KB[0], Data type: int64
# Column: OutPkt32s20iTr4KB[1], Data type: int64
# Column: OutPkt32s20iTr4KB[2], Data type: int64
# Column: OutPkt32s20iTr4KB[3], Data type: int64
# Column: OutPkt32s20iTr4KB[4], Data type: int64
# Column: OutPkt32s20iTr4KB[5], Data type: int64
# Column: OutPkt32s20iTr4KB[6], Data type: int64
# Column: OutPkt32s20iTr4KB[7], Data type: int64
# Column: OutPkt32s20iTr4KB[8], Data type: int64
# Column: OutPkt32s20iTr4KB[9], Data type: int64
# Column: OutPkt32s20iTr4KB[10], Data type: int64
# Column: OutPkt32s20iTr4KB[11], Data type: int64
# Column: OutPkt32s20iTr4KB[12], Data type: int64
# Column: OutPkt32s20iTr4KB[13], Data type: int64
# Column: OutPkt32s20iTr4KB[14], Data type: int64
# Column: OutPkt32s20iTr4KB[15], Data type: int64
# Column: OutPkt32s20iTr4KB[16], Data type: int64
# Column: OutPkt32s20iTr4KB[17], Data type: int64
# Column: OutPkt32s20iTr4KB[18], Data type: int64
# Column: OutPkt32s20iTr4KB[19], Data type: int64
# Column: OutPkt64s20iTr4KB[0], Data type: int64
# Column: OutPkt64s20iTr4KB[1], Data type: int64
# Column: OutPkt64s20iTr4KB[2], Data type: int64
# Column: OutPkt64s20iTr4KB[3], Data type: int64
# Column: OutPkt64s20iTr4KB[4], Data type: int64
# Column: OutPkt64s20iTr4KB[5], Data type: int64
# Column: OutPkt64s20iTr4KB[6], Data type: int64
# Column: OutPkt64s20iTr4KB[7], Data type: int64
# Column: OutPkt64s20iTr4KB[8], Data type: int64
# Column: OutPkt64s20iTr4KB[9], Data type: int64
# Column: OutPkt64s20iTr4KB[10], Data type: int64
# Column: OutPkt64s20iTr4KB[11], Data type: int64
# Column: OutPkt64s20iTr4KB[12], Data type: int64
# Column: OutPkt64s20iTr4KB[13], Data type: int64
# Column: OutPkt64s20iTr4KB[14], Data type: int64
# Column: OutPkt64s20iTr4KB[15], Data type: int64
# Column: OutPkt64s20iTr4KB[16], Data type: int64
# Column: OutPkt64s20iTr4KB[17], Data type: int64
# Column: OutPkt64s20iTr4KB[18], Data type: int64
# Column: OutPkt64s20iTr4KB[19], Data type: int64
# Column: InPkt64s20iTr2KB[0], Data type: int64
# Column: InPkt64s20iTr2KB[1], Data type: int64
# Column: InPkt64s20iTr2KB[2], Data type: int64
# Column: InPkt64s20iTr2KB[3], Data type: int64
# Column: InPkt64s20iTr2KB[4], Data type: int64
# Column: InPkt64s20iTr2KB[5], Data type: int64
# Column: InPkt64s20iTr2KB[6], Data type: int64
# Column: InPkt64s20iTr2KB[7], Data type: int64
# Column: InPkt64s20iTr2KB[8], Data type: int64
# Column: InPkt64s20iTr2KB[9], Data type: int64
# Column: InPkt64s20iTr2KB[10], Data type: int64
# Column: InPkt64s20iTr2KB[11], Data type: int64
# Column: InPkt64s20iTr2KB[12], Data type: int64
# Column: InPkt64s20iTr2KB[13], Data type: int64
# Column: InPkt64s20iTr2KB[14], Data type: int64
# Column: InPkt64s20iTr2KB[15], Data type: int64
# Column: InPkt64s20iTr2KB[16], Data type: int64
# Column: InPkt64s20iTr2KB[17], Data type: int64
# Column: InPkt64s20iTr2KB[18], Data type: int64
# Column: InPkt64s20iTr2KB[19], Data type: int64
# Column: InPkt64s20iTr1KB[0], Data type: int64
# Column: InPkt64s20iTr1KB[1], Data type: int64
# Column: InPkt64s20iTr1KB[2], Data type: int64
# Column: InPkt64s20iTr1KB[3], Data type: int64
# Column: InPkt64s20iTr1KB[4], Data type: int64
# Column: InPkt64s20iTr1KB[5], Data type: int64
# Column: InPkt64s20iTr1KB[6], Data type: int64
# Column: InPkt64s20iTr1KB[7], Data type: int64
# Column: InPkt64s20iTr1KB[8], Data type: int64
# Column: InPkt64s20iTr1KB[9], Data type: int64
# Column: InPkt64s20iTr1KB[10], Data type: int64
# Column: InPkt64s20iTr1KB[11], Data type: int64
# Column: InPkt64s20iTr1KB[12], Data type: int64
# Column: InPkt64s20iTr1KB[13], Data type: int64
# Column: InPkt64s20iTr1KB[14], Data type: int64
# Column: InPkt64s20iTr1KB[15], Data type: int64
# Column: InPkt64s20iTr1KB[16], Data type: int64
# Column: InPkt64s20iTr1KB[17], Data type: int64
# Column: InPkt64s20iTr1KB[18], Data type: int64
# Column: InPkt64s20iTr1KB[19], Data type: int64
# Column: OutPkt64s20iTr2KB[0], Data type: int64
# Column: OutPkt64s20iTr2KB[1], Data type: int64
# Column: OutPkt64s20iTr2KB[2], Data type: int64
# Column: OutPkt64s20iTr2KB[3], Data type: int64
# Column: OutPkt64s20iTr2KB[4], Data type: int64
# Column: OutPkt64s20iTr2KB[5], Data type: int64
# Column: OutPkt64s20iTr2KB[6], Data type: int64
# Column: OutPkt64s20iTr2KB[7], Data type: int64
# Column: OutPkt64s20iTr2KB[8], Data type: int64
# Column: OutPkt64s20iTr2KB[9], Data type: int64
# Column: OutPkt64s20iTr2KB[10], Data type: int64
# Column: OutPkt64s20iTr2KB[11], Data type: int64
# Column: OutPkt64s20iTr2KB[12], Data type: int64
# Column: OutPkt64s20iTr2KB[13], Data type: int64
# Column: OutPkt64s20iTr2KB[14], Data type: int64
# Column: OutPkt64s20iTr2KB[15], Data type: int64
# Column: OutPkt64s20iTr2KB[16], Data type: int64
# Column: OutPkt64s20iTr2KB[17], Data type: int64
# Column: OutPkt64s20iTr2KB[18], Data type: int64
# Column: OutPkt64s20iTr2KB[19], Data type: int64
# Column: OutPkt64s20iTr1KB[0], Data type: int64
# Column: OutPkt64s20iTr1KB[1], Data type: int64
# Column: OutPkt64s20iTr1KB[2], Data type: int64
# Column: OutPkt64s20iTr1KB[3], Data type: int64
# Column: OutPkt64s20iTr1KB[4], Data type: int64
# Column: OutPkt64s20iTr1KB[5], Data type: int64
# Column: OutPkt64s20iTr1KB[6], Data type: int64
# Column: OutPkt64s20iTr1KB[7], Data type: int64
# Column: OutPkt64s20iTr1KB[8], Data type: int64
# Column: OutPkt64s20iTr1KB[9], Data type: int64
# Column: OutPkt64s20iTr1KB[10], Data type: int64
# Column: OutPkt64s20iTr1KB[11], Data type: int64
# Column: OutPkt64s20iTr1KB[12], Data type: int64
# Column: OutPkt64s20iTr1KB[13], Data type: int64
# Column: OutPkt64s20iTr1KB[14], Data type: int64
# Column: OutPkt64s20iTr1KB[15], Data type: int64
# Column: OutPkt64s20iTr1KB[16], Data type: int64
# Column: OutPkt64s20iTr1KB[17], Data type: int64
# Column: OutPkt64s20iTr1KB[18], Data type: int64
# Column: OutPkt64s20iTr1KB[19], Data type: int64
# Column: BytesPerSecOut, Data type: float64
# Column: BytesPerSecIn, Data type: float64
# Column: BytesPerSessOut, Data type: int64
# Column: BytesPerSessIn, Data type: int64
# Column: Bytes3WH2FIN, Data type: int64
# Column: BytesTCPSess, Data type: int64
# Column: BytesTCPOverhead, Data type: int64
# Column: MedPktLenOut, Data type: float64
# Column: ModPktLenOut, Data type: int64
# Column: MeanPktLenOut, Data type: float64
# Column: SigPktLenOut, Data type: float64
# Column: SumPktLenOut, Data type: int64
# Column: MedPktLenIn, Data type: float64
# Column: ModPktLenIn, Data type: int64
# Column: MeanPktLenIn, Data type: float64
# Column: SigPktLenIn, Data type: float64
# Column: SumPktLenIn, Data type: int64
# Column: CntPktsOut, Data type: float64
# Column: CntPktsIn, Data type: float64
# Column: SumPktOut, Data type: int64
# Column: SumPktIn, Data type: int64
# Column: SumSYNPerSess, Data type: int64
# Column: SumSACKPerSess, Data type: int64
# Column: RatInOutB, Data type: float64
# Column: RatInOutPkt, Data type: float64
# Column: MedTTLIn, Data type: int64
# Column: ModTTLIn, Data type: int64
# Column: SigTTLIn, Data type: int64
# Column: MeanTTLIn, Data type: int64
# Column: SumTTLIn, Data type: int64
# Column: MedTTLOut, Data type: int64
# Column: ModTTLOut, Data type: int64
# Column: SigTTLOut, Data type: float64
# Column: MeanTTLOut, Data type: float64
# Column: SumTTLOut, Data type: int64
# Column: CntDataPktIn, Data type: int64
# Column: CntNondPktIn, Data type: int64
# Column: CntDataPktOut, Data type: int64
# Column: CntNondPktOut, Data type: int64
# Column: ModTosIp, Data type: int64
# Column: MedTosIp, Data type: int64
# Column: SigTCPHdrLen, Data type: float64
# Column: MeanTCPHdrLen, Data type: float64
# Column: SumTCPHdrLen, Data type: int64
# Column: ModTCPHdrLen, Data type: int64
# Column: MedTCPHdrLen, Data type: int64
# Column: HasFragIp, Data type: bool
# Column: SumFragPkt, Data type: int64
# Column: SumNfragPkt, Data type: int64
# Column: RatFragNfrag, Data type: int64
# Column: BPerSecIn, Data type: float64
# Column: BPerSecOut, Data type: float64
# Column: BPerSesIn, Data type: int64
# Column: BPerSesOut, Data type: int64
# Column: PktPerSIn, Data type: float64
# Column: PktPerSOut, Data type: float64
# Column: PktPerSesIn, Data type: int64
# Column: PktPerSesOut, Data type: int64
# Column: TSesStart, Data type: float64
# Column: TSesEnd, Data type: float64
# Column: SessDuration, Data type: float64
# Column: CntResendPktsIn, Data type: int64
# Column: CntResendPktsOut, Data type: int64
# Column: MedTdiff2Pkts, Data type: float64
# Column: MeanTdiff2Pkts, Data type: float64
# Column: SigTdiff2Pkts, Data type: float64
# Column: MedTdiff2PktsIn, Data type: float64
# Column: MeanTdiff2PktsIn, Data type: float64
# Column: SigTdiff2PktsIn, Data type: float64
# Column: MedTdiff2PktsOut, Data type: float64
# Column: MeanTdiff2PktsOut, Data type: float64
# Column: SigTdiff2PktsOut, Data type: float64
# Column: CntSYNIn, Data type: int64
# Column: CntACKIn, Data type: int64
# Column: CntFINIn, Data type: int64
# Column: CntSYNOut, Data type: int64
# Column: CntACKOut, Data type: int64
# Column: CntFINOut, Data type: int64
# Column: CntOfNewFlows, Data type: int64
# Column: CntOfOldFlows, Data type: int64
# Column: CorClosed, Data type: bool
# Column: PolyInd3ordOut[0], Data type: float64
# Column: PolyInd3ordOut[1], Data type: float64
# Column: PolyInd3ordOut[2], Data type: float64
# Column: PolyInd3ordOut[3], Data type: float64
# Column: PolyInd3ordIn[0], Data type: float64
# Column: PolyInd3ordIn[1], Data type: float64
# Column: PolyInd3ordIn[2], Data type: float64
# Column: PolyInd3ordIn[3], Data type: float64
# Column: PolyInd5ordOut[0], Data type: float64
# Column: PolyInd5ordOut[1], Data type: float64
# Column: PolyInd5ordOut[2], Data type: float64
# Column: PolyInd5ordOut[3], Data type: float64
# Column: PolyInd5ordOut[4], Data type: float64
# Column: PolyInd5ordOut[5], Data type: float64
# Column: PolyInd5ordIn[0], Data type: float64
# Column: PolyInd5ordIn[1], Data type: float64
# Column: PolyInd5ordIn[2], Data type: float64
# Column: PolyInd5ordIn[3], Data type: float64
# Column: PolyInd5ordIn[4], Data type: float64
# Column: PolyInd5ordIn[5], Data type: float64
# Column: PolyInd8ordOut[0], Data type: float64
# Column: PolyInd8ordOut[1], Data type: float64
# Column: PolyInd8ordOut[2], Data type: float64
# Column: PolyInd8ordOut[3], Data type: float64
# Column: PolyInd8ordOut[4], Data type: float64
# Column: PolyInd8ordOut[5], Data type: float64
# Column: PolyInd8ordOut[6], Data type: float64
# Column: PolyInd8ordOut[7], Data type: float64
# Column: PolyInd8ordOut[8], Data type: float64
# Column: PolyInd8ordIn[0], Data type: float64
# Column: PolyInd8ordIn[1], Data type: float64
# Column: PolyInd8ordIn[2], Data type: float64
# Column: PolyInd8ordIn[3], Data type: float64
# Column: PolyInd8ordIn[4], Data type: float64
# Column: PolyInd8ordIn[5], Data type: float64
# Column: PolyInd8ordIn[6], Data type: float64
# Column: PolyInd8ordIn[7], Data type: float64
# Column: PolyInd8ordIn[8], Data type: float64
# Column: PolyInd10ordOut[0], Data type: float64
# Column: PolyInd10ordOut[1], Data type: float64
# Column: PolyInd10ordOut[2], Data type: float64
# Column: PolyInd10ordOut[3], Data type: float64
# Column: PolyInd10ordOut[4], Data type: float64
# Column: PolyInd10ordOut[5], Data type: float64
# Column: PolyInd10ordOut[6], Data type: float64
# Column: PolyInd10ordOut[7], Data type: float64
# Column: PolyInd10ordOut[8], Data type: float64
# Column: PolyInd10ordOut[9], Data type: float64
# Column: PolyInd10ordOut[10], Data type: float64
# Column: PolyInd10ordIn[0], Data type: float64
# Column: PolyInd10ordIn[1], Data type: float64
# Column: PolyInd10ordIn[2], Data type: float64
# Column: PolyInd10ordIn[3], Data type: float64
# Column: PolyInd10ordIn[4], Data type: float64
# Column: PolyInd10ordIn[5], Data type: float64
# Column: PolyInd10ordIn[6], Data type: float64
# Column: PolyInd10ordIn[7], Data type: float64
# Column: PolyInd10ordIn[8], Data type: float64
# Column: PolyInd10ordIn[9], Data type: float64
# Column: PolyInd10ordIn[10], Data type: float64
# Column: PolyInd13ordOut[0], Data type: float64
# Column: PolyInd13ordOut[1], Data type: float64
# Column: PolyInd13ordOut[2], Data type: float64
# Column: PolyInd13ordOut[3], Data type: float64
# Column: PolyInd13ordOut[4], Data type: float64
# Column: PolyInd13ordOut[5], Data type: float64
# Column: PolyInd13ordOut[6], Data type: float64
# Column: PolyInd13ordOut[7], Data type: float64
# Column: PolyInd13ordOut[8], Data type: float64
# Column: PolyInd13ordOut[9], Data type: float64
# Column: PolyInd13ordOut[10], Data type: float64
# Column: PolyInd13ordOut[11], Data type: float64
# Column: PolyInd13ordOut[12], Data type: float64
# Column: PolyInd13ordOut[13], Data type: float64
# Column: PolyInd13ordIn[0], Data type: float64
# Column: PolyInd13ordIn[1], Data type: float64
# Column: PolyInd13ordIn[2], Data type: float64
# Column: PolyInd13ordIn[3], Data type: float64
# Column: PolyInd13ordIn[4], Data type: float64
# Column: PolyInd13ordIn[5], Data type: float64
# Column: PolyInd13ordIn[6], Data type: float64
# Column: PolyInd13ordIn[7], Data type: float64
# Column: PolyInd13ordIn[8], Data type: float64
# Column: PolyInd13ordIn[9], Data type: float64
# Column: PolyInd13ordIn[10], Data type: float64
# Column: PolyInd13ordIn[11], Data type: float64
# Column: PolyInd13ordIn[12], Data type: float64
# Column: PolyInd13ordIn[13], Data type: float64
# Column: PolyTime3ordOut[0], Data type: float64
# Column: PolyTime3ordOut[1], Data type: float64
# Column: PolyTime3ordOut[2], Data type: float64
# Column: PolyTime3ordOut[3], Data type: float64
# Column: PolyTime3ordIn[0], Data type: float64
# Column: PolyTime3ordIn[1], Data type: float64
# Column: PolyTime3ordIn[2], Data type: float64
# Column: PolyTime3ordIn[3], Data type: float64
# Column: PolyTime5ordOut[0], Data type: float64
# Column: PolyTime5ordOut[1], Data type: float64
# Column: PolyTime5ordOut[2], Data type: float64
# Column: PolyTime5ordOut[3], Data type: float64
# Column: PolyTime5ordOut[4], Data type: float64
# Column: PolyTime5ordOut[5], Data type: float64
# Column: PolyTime5ordIn[0], Data type: float64
# Column: PolyTime5ordIn[1], Data type: float64
# Column: PolyTime5ordIn[2], Data type: float64
# Column: PolyTime5ordIn[3], Data type: float64
# Column: PolyTime5ordIn[4], Data type: float64
# Column: PolyTime5ordIn[5], Data type: float64
# Column: PolyTime8ordOut[0], Data type: float64
# Column: PolyTime8ordOut[1], Data type: float64
# Column: PolyTime8ordOut[2], Data type: float64
# Column: PolyTime8ordOut[3], Data type: float64
# Column: PolyTime8ordOut[4], Data type: float64
# Column: PolyTime8ordOut[5], Data type: float64
# Column: PolyTime8ordOut[6], Data type: float64
# Column: PolyTime8ordOut[7], Data type: float64
# Column: PolyTime8ordOut[8], Data type: float64
# Column: PolyTime8ordIn[0], Data type: float64
# Column: PolyTime8ordIn[1], Data type: float64
# Column: PolyTime8ordIn[2], Data type: float64
# Column: PolyTime8ordIn[3], Data type: float64
# Column: PolyTime8ordIn[4], Data type: float64
# Column: PolyTime8ordIn[5], Data type: float64
# Column: PolyTime8ordIn[6], Data type: float64
# Column: PolyTime8ordIn[7], Data type: float64
# Column: PolyTime8ordIn[8], Data type: float64
# Column: PolyTime10ordOut[0], Data type: float64
# Column: PolyTime10ordOut[1], Data type: float64
# Column: PolyTime10ordOut[2], Data type: float64
# Column: PolyTime10ordOut[3], Data type: float64
# Column: PolyTime10ordOut[4], Data type: float64
# Column: PolyTime10ordOut[5], Data type: float64
# Column: PolyTime10ordOut[6], Data type: float64
# Column: PolyTime10ordOut[7], Data type: float64
# Column: PolyTime10ordOut[8], Data type: float64
# Column: PolyTime10ordOut[9], Data type: float64
# Column: PolyTime10ordOut[10], Data type: float64
# Column: PolyTime10ordIn[0], Data type: float64
# Column: PolyTime10ordIn[1], Data type: float64
# Column: PolyTime10ordIn[2], Data type: float64
# Column: PolyTime10ordIn[3], Data type: float64
# Column: PolyTime10ordIn[4], Data type: float64
# Column: PolyTime10ordIn[5], Data type: float64
# Column: PolyTime10ordIn[6], Data type: float64
# Column: PolyTime10ordIn[7], Data type: float64
# Column: PolyTime10ordIn[8], Data type: float64
# Column: PolyTime10ordIn[9], Data type: float64
# Column: PolyTime10ordIn[10], Data type: float64
# Column: PolyTime13ordOut[0], Data type: float64
# Column: PolyTime13ordOut[1], Data type: float64
# Column: PolyTime13ordOut[2], Data type: float64
# Column: PolyTime13ordOut[3], Data type: float64
# Column: PolyTime13ordOut[4], Data type: float64
# Column: PolyTime13ordOut[5], Data type: float64
# Column: PolyTime13ordOut[6], Data type: float64
# Column: PolyTime13ordOut[7], Data type: float64
# Column: PolyTime13ordOut[8], Data type: float64
# Column: PolyTime13ordOut[9], Data type: float64
# Column: PolyTime13ordOut[10], Data type: float64
# Column: PolyTime13ordOut[11], Data type: float64
# Column: PolyTime13ordOut[12], Data type: float64
# Column: PolyTime13ordOut[13], Data type: float64
# Column: PolyTime13ordIn[0], Data type: float64
# Column: PolyTime13ordIn[1], Data type: float64
# Column: PolyTime13ordIn[2], Data type: float64
# Column: PolyTime13ordIn[3], Data type: float64
# Column: PolyTime13ordIn[4], Data type: float64
# Column: PolyTime13ordIn[5], Data type: float64
# Column: PolyTime13ordIn[6], Data type: float64
# Column: PolyTime13ordIn[7], Data type: float64
# Column: PolyTime13ordIn[8], Data type: float64
# Column: PolyTime13ordIn[9], Data type: float64
# Column: PolyTime13ordIn[10], Data type: float64
# Column: PolyTime13ordIn[11], Data type: float64
# Column: PolyTime13ordIn[12], Data type: float64
# Column: PolyTime13ordIn[13], Data type: float64
# Column: FourGonModulIn[0], Data type: int64
# Column: FourGonModulIn[1], Data type: float64
# Column: FourGonModulIn[2], Data type: float64
# Column: FourGonModulIn[3], Data type: float64
# Column: FourGonModulIn[4], Data type: float64
# Column: FourGonModulIn[5], Data type: float64
# Column: FourGonModulIn[6], Data type: float64
# Column: FourGonModulIn[7], Data type: float64
# Column: FourGonModulIn[8], Data type: float64
# Column: FourGonModulIn[9], Data type: float64
# Column: FourGonModulIn[10], Data type: float64
# Column: FourGonModulIn[11], Data type: float64
# Column: FourGonModulIn[12], Data type: float64
# Column: FourGonModulIn[13], Data type: float64
# Column: FourGonModulIn[14], Data type: float64
# Column: FourGonModulIn[15], Data type: float64
# Column: FourGonModulIn[16], Data type: float64
# Column: FourGonModulIn[17], Data type: float64
# Column: FourGonModulIn[18], Data type: float64
# Column: FourGonModulIn[19], Data type: float64
# Column: FourGonAngleIn[0], Data type: int64
# Column: FourGonAngleIn[1], Data type: float64
# Column: FourGonAngleIn[2], Data type: float64
# Column: FourGonAngleIn[3], Data type: float64
# Column: FourGonAngleIn[4], Data type: float64
# Column: FourGonAngleIn[5], Data type: float64
# Column: FourGonAngleIn[6], Data type: float64
# Column: FourGonAngleIn[7], Data type: float64
# Column: FourGonAngleIn[8], Data type: float64
# Column: FourGonAngleIn[9], Data type: float64
# Column: FourGonAngleIn[10], Data type: float64
# Column: FourGonAngleIn[11], Data type: float64
# Column: FourGonAngleIn[12], Data type: float64
# Column: FourGonAngleIn[13], Data type: float64
# Column: FourGonAngleIn[14], Data type: float64
# Column: FourGonAngleIn[15], Data type: float64
# Column: FourGonAngleIn[16], Data type: float64
# Column: FourGonAngleIn[17], Data type: float64
# Column: FourGonAngleIn[18], Data type: float64
# Column: FourGonAngleIn[19], Data type: float64
# Column: FourGonModulOut[0], Data type: int64
# Column: FourGonModulOut[1], Data type: float64
# Column: FourGonModulOut[2], Data type: float64
# Column: FourGonModulOut[3], Data type: float64
# Column: FourGonModulOut[4], Data type: float64
# Column: FourGonModulOut[5], Data type: float64
# Column: FourGonModulOut[6], Data type: float64
# Column: FourGonModulOut[7], Data type: float64
# Column: FourGonModulOut[8], Data type: float64
# Column: FourGonModulOut[9], Data type: float64
# Column: FourGonModulOut[10], Data type: float64
# Column: FourGonModulOut[11], Data type: float64
# Column: FourGonModulOut[12], Data type: float64
# Column: FourGonModulOut[13], Data type: float64
# Column: FourGonModulOut[14], Data type: float64
# Column: FourGonModulOut[15], Data type: float64
# Column: FourGonModulOut[16], Data type: float64
# Column: FourGonModulOut[17], Data type: float64
# Column: FourGonModulOut[18], Data type: float64
# Column: FourGonModulOut[19], Data type: float64
# Column: FourGonAngleOut[0], Data type: int64
# Column: FourGonAngleOut[1], Data type: float64
# Column: FourGonAngleOut[2], Data type: float64
# Column: FourGonAngleOut[3], Data type: float64
# Column: FourGonAngleOut[4], Data type: float64
# Column: FourGonAngleOut[5], Data type: float64
# Column: FourGonAngleOut[6], Data type: float64
# Column: FourGonAngleOut[7], Data type: float64
# Column: FourGonAngleOut[8], Data type: float64
# Column: FourGonAngleOut[9], Data type: float64
# Column: FourGonAngleOut[10], Data type: float64
# Column: FourGonAngleOut[11], Data type: float64
# Column: FourGonAngleOut[12], Data type: float64
# Column: FourGonAngleOut[13], Data type: float64
# Column: FourGonAngleOut[14], Data type: float64
# Column: FourGonAngleOut[15], Data type: float64
# Column: FourGonAngleOut[16], Data type: float64
# Column: FourGonAngleOut[17], Data type: float64
# Column: FourGonAngleOut[18], Data type: float64
# Column: FourGonAngleOut[19], Data type: float64
# Column: IntervalsPortsSig, Data type: int64
# Column: IntervalsPortsSig2, Data type: int64
# Column: IntervalsIPsSig, Data type: float64
# Column: IntervalsIPsSig2, Data type: float64
# Column: GaussProds1In[0], Data type: float64
# Column: GaussProds2In[0], Data type: float64
# Column: GaussProds2In[1], Data type: float64
# Column: GaussProds4In[0], Data type: float64
# Column: GaussProds4In[1], Data type: float64
# Column: GaussProds4In[2], Data type: float64
# Column: GaussProds4In[3], Data type: float64
# Column: GaussProds8In[0], Data type: float64
# Column: GaussProds8In[1], Data type: float64
# Column: GaussProds8In[2], Data type: float64
# Column: GaussProds8In[3], Data type: float64
# Column: GaussProds8In[4], Data type: float64
# Column: GaussProds8In[5], Data type: float64
# Column: GaussProds8In[6], Data type: float64
# Column: GaussProds8In[7], Data type: float64
# Column: GaussProds1Out[0], Data type: float64
# Column: GaussProds2Out[0], Data type: float64
# Column: GaussProds2Out[1], Data type: float64
# Column: GaussProds4Out[0], Data type: float64
# Column: GaussProds4Out[1], Data type: float64
# Column: GaussProds4Out[2], Data type: float64
# Column: GaussProds4Out[3], Data type: float64
# Column: GaussProds8Out[0], Data type: float64
# Column: GaussProds8Out[1], Data type: float64
# Column: GaussProds8Out[2], Data type: float64
# Column: GaussProds8Out[3], Data type: float64
# Column: GaussProds8Out[4], Data type: float64
# Column: GaussProds8Out[5], Data type: float64
# Column: GaussProds8Out[6], Data type: float64
# Column: GaussProds8Out[7], Data type: float64
# Column: GaussProds1All[0], Data type: float64
# Column: GaussProds2All[0], Data type: float64
# Column: GaussProds2All[1], Data type: float64
# Column: GaussProds4All[0], Data type: float64
# Column: GaussProds4All[1], Data type: float64
# Column: GaussProds4All[2], Data type: float64
# Column: GaussProds4All[3], Data type: float64
# Column: GaussProds8All[0], Data type: float64
# Column: GaussProds8All[1], Data type: float64
# Column: GaussProds8All[2], Data type: float64
# Column: GaussProds8All[3], Data type: float64
# Column: GaussProds8All[4], Data type: float64
# Column: GaussProds8All[5], Data type: float64
# Column: GaussProds8All[6], Data type: float64
# Column: GaussProds8All[7], Data type: float64
#
# Columns with null values:
# No null values are found in any columns.

# %%
# Basic Data Inpection : Dataset Summary Inspection
data_inspector.set_strategy(SummaryStatisticsInspectionStrategy())
data_inspector.execute_inspection(df)
# Out:
# Summary Statistics (Numerical Features):
#                 id       SrcPort      DstPort  InPkt1s10i[0]  InPkt1s10i[1]  \
# count  5771.000000   5771.000000  5771.000000    5771.000000    5771.000000
# mean   2886.000000  39220.685843   340.984925       7.046959       7.456247
# std    1666.088533  24358.193471   725.021824       7.289772       9.367462
# min       1.000000   1032.000000    25.000000       0.000000       0.000000
# 25%    1443.500000   3981.500000    80.000000       2.000000       3.000000
# 50%    2886.000000  54457.000000    80.000000       5.000000       4.000000
# 75%    4328.500000  56996.000000   443.000000       8.000000       7.000000
# max    5771.000000  65533.000000  5222.000000      34.000000      41.000000
#
#        InPkt1s10i[2]  InPkt1s10i[3]  InPkt1s10i[4]  InPkt1s10i[5]  \
# count    5771.000000    5771.000000    5771.000000    5771.000000
# mean        7.514815       6.808525       7.348986       6.960319
# std         9.934251       9.687397       9.813364       9.831033
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.000000       0.000000       0.000000
# 50%         5.000000       4.000000       5.000000       4.000000
# 75%         8.000000       6.000000       7.000000       7.000000
# max        42.000000      41.000000      42.000000      41.000000
#
#        InPkt1s10i[6]  ...  GaussProds4All[2]  GaussProds4All[3]  \
# count    5771.000000  ...        5771.000000        5771.000000
# mean        6.873332  ...          52.997624          16.450495
# std         9.593184  ...          27.213690           8.678672
# min         0.000000  ...           0.000000           0.000000
# 25%         0.000000  ...          31.481918          13.669718
# 50%         4.000000  ...          60.799822          13.669718
# 75%         7.000000  ...          67.949911          17.077766
# max        41.000000  ...         295.833151         152.628150
#
#        GaussProds8All[0]  GaussProds8All[1]  GaussProds8All[2]  \
# count        5771.000000        5771.000000        5771.000000
# mean           22.062825          29.577259         118.589119
# std            11.592764          20.182041          76.973307
# min             0.000000           0.000000           0.000000
# 25%            15.243286          25.029644          50.895882
# 50%            23.817482          27.633154         106.651292
# 75%            30.142188          33.082724         195.268837
# max           152.913247         194.958609         485.259912
#
#        GaussProds8All[3]  GaussProds8All[4]  GaussProds8All[5]  \
# count        5771.000000        5771.000000        5771.000000
# mean           40.282891         112.217032          59.488651
# std            60.324614          86.172839          52.455015
# min             0.000000           0.000000           0.000000
# 25%            19.032869          38.144083          28.710093
# 50%            29.236968          84.481713          29.286233
# 75%            30.527151         187.688933          94.389872
# max           576.637652         570.721134         468.445811
#
#        GaussProds8All[6]  GaussProds8All[7]
# count        5771.000000        5771.000000
# mean           32.538063          16.191687
# std            35.952925           6.978461
# min             0.000000           0.000000
# 25%            22.347789          14.791910
# 50%            30.244259          16.262570
# 75%            31.702502          16.289161
# max           470.140068         153.011199
#
# [8 rows x 867 columns]
#
# Summary Statistics (Categorical Features):
#        label_2 label_poly         SrcIP        DstIP             SrcMAC  \
# count     5771       5771          5771         5771               5771
# unique       2          5            34            8                  4
# top      False   0_apache  10.2.197.241  10.1.60.187  00:1E:7A:21:B4:00
# freq      5727       2911          3148         5437               5384
#
#                    DstMAC SrcIPInVlan DstIPInVlan HasFragIp CorClosed
# count                5771        5771        5771      5771      5771
# unique                  2           2           2         1         2
# top     00:1A:6C:FB:3D:F0       False        True     False      True
# freq                 5736        5384        5736      5771      4516

# %% [markdown]
# ## **INSIGHTS**
#
# ### 1. Data Types and Null Counts
# - The Dataset contains 5771 entries.
# - **Data Types**: There are 5 columns of boolean and object data type, 331 columns of float type, 536 columns of int64 type.
#     - There are no null values, which is expected since ASNM-CDX-2009 dataset is collected by monitoring the network traffic, the chances of null values being there is near zero.
#
# ### 2. Summary Statistics:
# - **Numerical Features**:
#     Most of the numerical features such as

# %%
analysis = SimpleMissingValueAnalysis()
analysis.analyze(df)
# Out:
# No missing values.
